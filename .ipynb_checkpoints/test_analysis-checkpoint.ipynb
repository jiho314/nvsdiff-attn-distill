# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('check_points/1105_mix_2to2.csv')
# data0 = pd.read_csv('check_points/1031_mix.csv')

# data0 = data0[["run_name","dataset","cond_num","view_range","train_step","psnr","ssim","lpips"]]
print(len(data[data.duplicated()]))
data = data.drop_duplicates()
data
# Out:
# 0
#                         run_name  cond_num  \
# 0                  1105_naive_b8         1
# 1  1105_distill_b8_mlp1_L10_lw01         1
# 2  1105_distill_b8_mlp1_L10_lw01         1
# 3                  1105_naive_b8         1
# 4                  1105_naive_b8         1
# 5  1105_distill_b8_mlp1_L10_lw01         1
# 6                  1105_naive_b8         1
# 7  1105_distill_b8_mlp1_L10_lw01         1
#
#                                    dataset_full dataset  view_range  \
# 0                     re10k_wds_val_refidx0_4_6   re10k           6
# 1                     re10k_wds_val_refidx0_4_6   re10k           6
# 2  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
# 3  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
# 4  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
# 5  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
# 6  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
# 7  co3d_wds_val_subset_unseen_scene_refidx1_4_8    co3d           8
#
#    train_step       psnr      ssim     lpips  psnr_masked  psnr_unmasked
# 0       10000  15.651726  0.583496  0.434570    15.862986      14.850794
# 1       10000  15.350051  0.582031  0.443604    15.604891      14.358815
# 2       20000  13.033171  0.502930  0.591797    13.108748      13.628172
# 3       20000  13.412012  0.518555  0.594238    13.411277      14.217226
# 4       40000  12.996553  0.522949  0.599121    13.155877      13.253772
# 5       40000  13.055412  0.524414  0.593262    13.114089      13.402852
# 6       60000  13.599974  0.525879  0.576660    13.609020      14.348124
# 7       60000  13.307908  0.522949  0.579590    13.422110      13.814635

# %%
cond_num =[0,1]
value ="psnr"
# --
df = data[(data["cond_num"].isin(cond_num)) & (data["train_step"] > 10) & (data["dataset"] == "co3d")] #& (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
# df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()
# df_avg_psnr_unmasked = df.groupby(["run_name", "train_step"])["psnr_unmasked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    elif "distill" in run:
        label = "CAMEO"
        c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[2]
value ="psnr"
# --
df = data[(data["cond_num"].isin(cond_num))  & (data["view_range"] == 0) ] # &(~data["train_step"].isin([20000, 100000, 60000])) & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
# df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    elif "distill" in run:
        label = "CAMEO"
        c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[2]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num))  & (data["view_range"] == 14) ] # &(~data["train_step"].isin([20000, 100000, 60000])) & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    elif "distill" in run:
        label = "CAMEO"
        c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[2]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num)) & (data["view_range"] == 6)  ] # &(~data["train_step"].isin([20000, 100000, 60000])) & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    elif "distill" in run:
        label = "CAMEO"
        c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[1]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num)) & (data["view_range"] == 10)  ] # &(~data["train_step"].isin([20000, 100000, 60000])) & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    elif "distill" in run:
        label = "CAMEO"
        c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[1]
value ="psnr"
# --
df = data[(data["cond_num"].isin(cond_num)) &(~data["train_step"].isin([20000, 100000, 60000])) ] # & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
# df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    c = None
    if 'naive' in run:
        label = "Baseline"
    elif 'repa' in run:
        label = "REPA"
    # elif "distill" in run:
    #     label = "CAMEO"
    #     c = 'g'
    else:
        label = run
    plt.plot(subset["train_step"], subset[value], marker="o",c=c, label=label)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[1,2]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num)) & (~data['train_step'].isin([20000,60000,100000 ]))  &(~data['run_name'].isin([])) ] # & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    plt.plot(subset["train_step"], subset[value], marker="o", label=run)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[1]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num)) & (~data['train_step'].isin([20000, 60000, 100000]))   ] # & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    plt.plot(subset["train_step"], subset[value], marker="o", label=run)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()

# %%
cond_num =[1]
value ="psnr_masked"
# --
df = data[(data["cond_num"].isin(cond_num)) & (~data['train_step'].isin([]))  & (data["view_range"] == 6)  ] # & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
# df = df[(data["cond_num"].isin([cond_num])
# df = data
# df = data
# --- Group by run_name + train_step, average psnr ---
df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
df_avg_ssim = df.groupby(["run_name", "train_step"])["ssim"].mean().reset_index()
df_avg_lpips = df.groupby(["run_name", "train_step"])["lpips"].mean().reset_index()
df_avg_psnr_masked = df.groupby(["run_name", "train_step"])["psnr_masked"].mean().reset_index()

plot_df = eval(f"df_avg_{value}")
plt.figure(figsize=(8,6))
for run in plot_df["run_name"].unique():
    subset = plot_df[plot_df["run_name"] == run]
    plt.plot(subset["train_step"], subset[value], marker="o", label=run)


plt.xlabel("Train Step")
plt.ylabel(f"{value} (avg)")
plt.title(f"{value} (cond_num ={cond_num})")#(view_range=(6/10)(10/14))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 value ="psnr_masked"
#       3 # --
# ----> 4 df = data[(data["cond_num"].isin(cond_num)) & (~data['train_step'].isin([]))  & (data["view_range"] == 6)  ] # & (data["view_range"] == 10) #& (data["train_step"] != 60000)  120000 80000 40000 20000 10000
#       5 # df = df[(data["cond_num"].isin([cond_num])
#       6 # df = data
#       7 # df = data
#       8 # --- Group by run_name + train_step, average psnr ---
#       9 df_avg_psnr = df.groupby(["run_name", "train_step"])["psnr"].mean().reset_index()
#
# NameError: name 'data' is not defined

# %%
data3[(data3['train_step']==200000) ].sort()#& (data3['run_name'] == '0922_distill_perview_lr25_mlp1_L10_lw02')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1177347/499389035.py in ?()
# ----> 1 data3[(data3['train_step']==200000) ] .sort()#& (data3['run_name'] == '0922_distill_perview_lr25_mlp1_L10_lw02')]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data0[(data0['train_step']==200000)& (data0['run_name'] == '0919_naive_b3_lr2.5')]
# Out:
#               run_name dataset  cond_num  view_range  train_step       psnr  \
# 0  0919_naive_b3_lr2.5   re10k         1           6      200000  18.477650
# 1  0919_naive_b3_lr2.5   re10k         2          10      200000  19.478687
# 2  0919_naive_b3_lr2.5   re10k         2          14      200000  18.409502
# 3  0919_naive_b3_lr2.5   re10k         1          10      200000  16.568888
#
#        ssim     lpips  psnr_masked
# 0  0.653613  0.230420          NaN
# 1  0.680556  0.203995          NaN
# 2  0.651417  0.252754          NaN
# 3  0.603447  0.319882          NaN
